# %%
import model_HCCT
# from util.option import args
# Out:
# usage: ipykernel_launcher.py [-h] [--debug] [--template TEMPLATE]
#                              [--n_threads N_THREADS] [--cpu] [--n_GPUs N_GPUS]
#                              [--seed SEED] [--dir_data DIR_DATA]
#                              [--dir_demo DIR_DEMO] [--data_train DATA_TRAIN]
#                              [--data_test DATA_TEST] [--data_range DATA_RANGE]
#                              [--ext EXT] [--scale SCALE]
#                              [--patch_size PATCH_SIZE] [--rgb_range RGB_RANGE]
#                              [--n_colors N_COLORS] [--chop] [--no_augment]
#                              [--model MODEL] [--act ACT]
#                              [--pre_train PRE_TRAIN] [--extend EXTEND]
#                              [--n_resblocks N_RESBLOCKS] [--n_feats N_FEATS]
#                              [--res_scale RES_SCALE] [--shift_mean SHIFT_MEAN]
#                              [--dilation] [--precision {single,half}]
# ...

# %%
model = model_HCCT.Model(args, checkpoint)
